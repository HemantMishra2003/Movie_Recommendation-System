# %%
import numpy as np 
import pandas as pd

# %%
v = pd.read_csv("movies-tmdb-10000.csv")

# %%
v.head(2)
# Out:
#       id                        title                 genre original_language  \
# 0    278     The Shawshank Redemption           Drama,Crime                en
# 1  19404  Dilwale Dulhania Le Jayenge  Comedy,Drama,Romance                hi
#
#                                             overview  popularity release_date  \
# 0  Framed in the 1940s for the double murder of h...      94.075   1994-09-23
# 1  Raj is a rich, carefree, happy-go-lucky second...      25.408   1995-10-19
#
#    vote_average  vote_count
# 0           8.7       21862
# 1           8.7        3731

# %%
# we can see here my  how many columns are present 
# in my original movie dataset

# %%
v.columns.tolist()

# we can see here my  how many columns are present 
# in my original movie dataset
# Out:
# ['id',
#  'title',
#  'genre',
#  'original_language',
#  'overview',
#  'popularity',
#  'release_date',
#  'vote_average',
#  'vote_count']

# %%
v.shape
#   1000 rows and 16 columns are there
# Out:
# (10000, 9)

# %%
v.isnull().sum()
# only in 2 columns ,  our data is missing 
# since  we will impute rather than droping 
# the column because
# Out:
# id                    0
# title                 0
# genre                 3
# original_language     0
# overview             13
# popularity            0
# release_date          0
# vote_average          0
# vote_count            0
# dtype: int64

# %%
# we are filling the missing value of overview 
# genre
v["overview"].fillna("Not Available",inplace=True)
v["genre"].fillna("- - -",inplace=True)
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_35412\451296821.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   v["overview"].fillna("Not Available",inplace=True)
# C:\Users\rahul\AppData\Local\Temp\ipykernel_35412\451296821.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
v.isnull().sum()
# now no any  values is missing
# Out:
# id                   0
# title                0
# genre                0
# original_language    0
# overview             0
# popularity           0
# release_date         0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
# this is the code of text vectorization
#

from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000, stop_words="english")

# %%
v  =  movies_overview 

# we can see here my  how many columns are present 
# in my original movie dataset

# %%
v["overview"][1]
# Out:
# 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.'

# %%
movies_overview = v

# we can see here my  how many columns are present 
# in my original movie dataset

# %%
movies =v[['id', 'title', 'overview', 'genre']]

# %%
movies.head(2)
# Out:
#       id                        title  \
# 0    278     The Shawshank Redemption
# 1  19404  Dilwale Dulhania Le Jayenge
#
#                                             overview                 genre
# 0  Framed in the 1940s for the double murder of h...           Drama,Crime
# 1  Raj is a rich, carefree, happy-go-lucky second...  Comedy,Drama,Romance

# %%
movies['tags'] = movies['overview'] + movies['genre']
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_35412\2958959546.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['tags'] = movies['overview'] + movies['genre']

# %%
new_movies  = movies.drop(columns=['overview', 'genre'])
new_movies.head()

# what we did here is to  first we add drop and genre in single column 
#  tag then we dropped both column  and made new dataset
# Out:
#       id                        title  \
# 0    278     The Shawshank Redemption
# 1  19404  Dilwale Dulhania Le Jayenge
# 2    238                The Godfather
# 3    424             Schindler's List
# 4    240       The Godfather: Part II
#
#                                                 tags
# 0  Framed in the 1940s for the double murder of h...
# 1  Raj is a rich, carefree, happy-go-lucky second...
# 2  Spanning the years 1945 to 1955, a chronicle o...
# 3  The true story of how businessman Oskar Schind...
# 4  In the continuing saga of the Corleone crime f...

# %%
new_movies["tags"][1]
# Out:
# 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.Comedy,Drama,Romance'

# %%
from sklearn.feature_extraction.text import CountVectorizer

# so this line converts our text data into 
# numerical data ... actually what does it mean 
# that suppose  we have text 1 and text 2 ...
# so it will make a matrix of text 1 and text 2 
# and make a column of  words ... like words  
# i love thriller 
#  i love  roamnce 
# so by numerica coding it will tell the percentage of matching
# and used for recommending purpose from the basis ofd 1 movie

# %%
cv=CountVectorizer(max_features=10000, stop_words='english')
# since we have  10000 rows  and in tags there is so many words
#  so it will remove common words like and , the , is 
# because for tag puprpose it is irrelevent features

# %%
cv
# Out:
# CountVectorizer(max_features=10000, stop_words='english')

# %%
vectors =cv.fit_transform(new_movies['tags'].values.astype('U')).toarray()

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vector)
similarity
# Out:
# array([[1.        , 0.05555556, 0.12858612, ..., 0.0745356 , 0.10910895,
#         0.06804138],
#        [0.05555556, 1.        , 0.07715167, ..., 0.        , 0.03636965,
#         0.        ],
#        [0.12858612, 0.07715167, 1.        , ..., 0.02300219, 0.0673435 ,
#         0.09449112],
#        ...,
#        [0.0745356 , 0.        , 0.02300219, ..., 1.        , 0.03253   ,
#         0.03042903],
#        [0.10910895, 0.03636965, 0.0673435 , ..., 0.03253   , 1.        ,
#         0.04454354],
#        [0.06804138, 0.        , 0.09449112, ..., 0.03042903, 0.04454354,
#         1.        ]])

# %%
new_movies[new_movies['title']=="The Godfather"].index[0]
# Out:
# 2

# %%
distance = sorted(list(enumerate(similarity[2])), reverse=True, key=lambda vector:vector[1])
for i in distance[0:5]:
    print(new_movies.iloc[i[0]].title)
# Out:
# The Godfather
# The Godfather: Part II
# Blood Ties
# Joker
# Bomb City

# %%
def recommand(movies):
    index=new_movies[new_movies['title']==movies].index[0]
    distance = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda vector:vector[1])
    for i in distance[0:5]:
        print(new_movies.iloc[i[0]].title)

# %%
recommand("Iron Man")
# Out:
# Iron Man
# Iron Man 3
# Guardians of the Galaxy Vol. 2
# Avengers: Age of Ultron
# Star Wars: Episode III - Revenge of the Sith

# %%
import pickle
pickle.dump(new_movies, open('movies_list.pkl', 'wb'))

# %%
pickle.dump(similarity, open('similarity.pkl', 'wb'))

# %%
pickle.load(open('movies_list.pkl', 'rb'))
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                    tags
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
pickle.dump(movies_overview, open('movies_overview.pkl', 'wb'))

# %%
pickle.load(open('movies_overview.pkl', 'rb'))
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                  genre original_language  \
# 0                                          Drama,Crime                en
# 1                                 Comedy,Drama,Romance                hi
# ...
